# %% [markdown]
# <a href="https://colab.research.google.com/github/LavanyaPanja/Sentiment_Analysis_Using_Python/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
 
urls=['https://inshorts.com/en/read/sports','https://inshorts.com/en/read/world','https://inshorts.com/en/read/politics']
def build_dataset(urls):
  news_data=[]
  for url in urls:
    news_category=url.split('/')[-1]
    data=requests.get(url) 
    soup=BeautifulSoup(data.content)
 
    news_articles=[{'news_headline':headline.find('span',attrs={"itemprop":"headline"}).string,'news_article':article.find('div',attrs={"itemprop":"articleBody"}).string,'news_category':news_category}for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),soup.find_all('div',class_=["news-card-content news-right-box"]))]
    news_articles=news_articles[0:20]
    news_data.extend(news_articles)
  df=pd.DataFrame(news_data)
  df=df[['news_headline','news_article','news_category']]
  return df

# %%
df=build_dataset(urls) 
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  India win 3rd ODI in last over, clinch 6th str...  ...        sports
# 1  8 batsmen scored 1 or less during the lowest-e...  ...        sports
# 2  How does Cricket World Cup Super League points...  ...        sports
# 3  Quite surprised Shardul Thakur was not named M...  ...        sports
# 4  Thisara Perera smashes 6 sixes in an over, bec...  ...        sports
#
# [5 rows x 3 columns]

# %%
df.tail()
# Out:
#                                         news_headline  ... news_category
# 55  Centre made fuel prices cheaper by 17-18 paise...  ...      politics
# 56  Punjab BJP leaders protest outside CM's reside...  ...      politics
# 57  Not fighting to win but to save Assam from BJP...  ...      politics
# 58  Ramesh Jarkiholi's supporters attack Shivakuma...  ...      politics
# 59  Mind games won't work in Bengal: Derek on Shah...  ...      politics
#
# [5 rows x 3 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/LavanyaPanja/Sentiment_Analysis_Using_Python/main/news.csv')

# %%
df
# Out:
#                                         news_headline  ... news_category
# 0   England complete their biggest run chase again...  ...        sports
# 1   Sachin first opened in ODIs due to Sidhu's 'st...  ...        sports
# 2   Kuldeep Yadav gives away most sixes by an Indi...  ...        sports
# 3   KL Rahul reveals reason behind covering his ea...  ...        sports
# 4     Sachin Tendulkar tests positive for coronavirus  ...        sports
# 5   Stokes mistakenly applies saliva on the ball f...  ...        sports
# 6   Hardik runs towards Sam Curran after getting s...  ...        sports
# 7   Why was Pant denied 4 runs despite the ball cr...  ...        sports
# 8   I never played for hundreds in my life: Kohli ...  ...        sports
# 9   How does the Cricket World Cup Super League po...  ...        sports
# 10  3rd umpire's decision on India's run-out appea...  ...        sports
# 11  My phone is on, Gavaskar more than welcome to ...  ...        sports
# 12  Too risky: VVS Laxman on India's 5-bowler stra...  ...        sports
# 13  Sehwag criticises India's decision to not bowl...  ...        sports
# 14  Why are teams wearing 'Human Rights' T-shirts ...  ...        sports
# 15  Adil Rashid 2nd bowler to dismiss Kohli 9 time...  ...        sports
# 16  Faced Haryana men's team bowlers to improve: 1...  ...        sports
# 17  Saina enters semi-finals of a tournament for 1...  ...        sports
# 18  He'll be disappointed: Gavaskar on Kohli's 7 5...  ...        sports
# 19  Really honoured: Shakib Al Hasan after meeting...  ...        sports
# 20  What did WHO say about India's decision to mak...  ...         world
# 21  Earth safe for over 100 yrs from asteroid Apop...  ...         world
# 22  It's undiplomatic: India after Saudi's advice ...  ...         world
# 23  US adds India to list of regions affected by A...  ...         world
# 24  PM Modi prays to Maa Kali to free human race f...  ...         world
# 25  Satellite images show traffic jam caused by co...  ...         world
# 26  Pakistan Interior Ministry refuses to renew ex...  ...         world
# 27  Plan made to refloat huge container ship block...  ...         world
# 28  Myanmar civil disobedience movement nominated ...  ...         world
# 29  Fake coronavirus vaccines are being sold onlin...  ...         world
# 30  WHO urges countries to donate 1 crore vaccine ...  ...         world
# 31  Thailand plans to allow quarantine-free entry ...  ...         world
# 32  Britain's medicine regulator approves 20-secon...  ...         world
# 33  FB freezes Venezuela Prez's page over COVID-19...  ...         world
# 34  Biden invites 40 world leaders including PM Mo...  ...         world
# 35  JICA to extend ₹3717 cr loan to fund 2nd phase...  ...         world
# 36  US firm sues Fox News for $1.6 bn over 'false'...  ...         world
# 37  Oil jumps 4% on fears Suez Canal blockage may ...  ...         world
# 38  Pak successfully test fires nuclear-capable ba...  ...         world
# 39  China imposes duties of up to 218% on Australi...  ...         world
# 40  Voting begins for 1st phase of Assembly electi...  ...      politics
# 41  Over 100 EVMs found to be non-functional in se...  ...      politics
# 42  Shashi Tharoor says 'sorry' after tweet on PM ...  ...      politics
# 43  Tea leaves not fully grown but Priyanka plucks...  ...      politics
# 44  SC orders transfer of MLA Ansari from Punjab t...  ...      politics
# 45  Gold smuggling accused not held in 9 months?: ...  ...      politics
# 46  Vote wisely: Manmohan Singh in video message a...  ...      politics
# 47  Kerala govt orders judicial probe against ED i...  ...      politics
# 48  Hotel rooms near Gir Sanctuary rose from 25 to...  ...      politics
# 49  Uttar Pradesh Panchayat polls to be held in 4 ...  ...      politics
# 50  CAA was brought to divide people of the countr...  ...      politics
# 51  BJP announces candidates for Lok Sabha bypolls...  ...      politics
# 52  5 hurt in explosion at TMC office in Bengal's ...  ...      politics
# 53  Ruckus in Bihar Assembly an attack on democrac...  ...      politics
# 54  How many more deaths is state waiting for?: Fa...  ...      politics
# 55  I'm a farmer: Tamil Nadu CM on DMK leader's 's...  ...      politics
# 56  Suvendu writes to EC, seeks several police off...  ...      politics
# 57  TMC workers trying to create disturbance: BJP ...  ...      politics
# 58  Congress stages protests against farm laws in ...  ...      politics
# 59  Vehicle returning after delivering food to WB ...  ...      politics
#
# [60 rows x 3 columns]

# %%
import nltk
nltk.download('stopwords')
stopword_list=nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 177

# %%
#remove HTML TAG
def html_tag(text):
  soup=BeautifulSoup(text,"html.parser")
  news_text=soup.get_text()
  return news_text
html_tag('<hmtl><h2>so good</h2></html>')
# Out:
# 'so good'

# %%
#Expand contractions
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.7/dist-packages (0.0.48)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.7/dist-packages (from contractions) (0.0.21)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (1.4.2)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (0.1.7)

# %%
import contractions
def con(text):
  expand=contractions.fix(text) 
  return expand
con("I've never been cool - and I don't care. Celine Dion. ...  ")
# Out:
# 'I have never been cool - and I do not care. Celine Dion. ...  '

# %%
import re
def remove_sp(text):
  pattern=r'[^A-Za-z0-9\s]'
  text=re.sub(pattern,'',text) 
  return text
remove_sp('“If I were a tree at ,@smartknower.com, $I would have no reason to love a human .”€symbol ... ')
# Out:
# 'If I were a tree at smartknowercom I would have no reason to love a human symbol  '

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer=ToktokTokenizer()

# %%
def remove_stopwords(text):
  tokens=tokenizer.tokenize(text)
  tokens=[token.strip() for token in tokens]
  filtered_tokens=[token for token in tokens if token not in stopword_list]
  filtered_text=' '.join(filtered_tokens) 
  return filtered_text

# %%
remove_stopwords("it is an example to remove stopwords ")
# Out:
# 'example remove stopwords'

# %%
#lower case
# contractions
# HTML tag
#Special characters
# stopwords
 
df.news_headline=df.news_headline.apply(lambda x:x.lower())
df.news_article=df.news_article.apply(lambda x:x.lower()) 
df.news_headline=df.news_headline.apply(html_tag)
df.news_article=df.news_article.apply(html_tag)
 
df.news_headline=df.news_headline.apply(con)
df.news_article=df.news_article.apply(con)
df.news_headline=df.news_headline.apply(remove_sp)
df.news_article=df.news_article.apply(remove_sp)
df.news_headline=df.news_headline.apply(remove_stopwords)
df.news_article=df.news_article.apply(remove_stopwords)

# %%
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  england complete biggest run chase india odi h...  ...        sports
# 1     sachin first opened odis due sidhus stiff neck  ...        sports
# 2   kuldeep yadav gives away sixes indian bowler odi  ...        sports
# 3  kl rahul reveals reason behind covering ears f...  ...        sports
# 4        sachin tendulkar tests positive coronavirus  ...        sports
#
# [5 rows x 3 columns]

# %%
df.tail()
# Out:
#                                         news_headline  ... news_category
# 55  I farmer tamil nadu cm dmk leaders slipper remark  ...      politics
# 56  suvendu writes ec seeks several police officer...  ...      politics
# 57  tmc workers trying create disturbance bjp cand...  ...      politics
# 58     congress stages protests farm laws maharashtra  ...      politics
# 59  vehicle returning delivering food wb poll work...  ...      politics
#
# [5 rows x 3 columns]

# %%
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.7/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs=SentimentIntensityAnalyzer()

# %%
df['compound']=df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])

# %%
df
# Out:
#                                         news_headline  ... compound
# 0   england complete biggest run chase india odi h...  ...   0.0000
# 1      sachin first opened odis due sidhus stiff neck  ...  -0.0093
# 2    kuldeep yadav gives away sixes indian bowler odi  ...   0.0772
# 3   kl rahul reveals reason behind covering ears f...  ...   0.7377
# 4         sachin tendulkar tests positive coronavirus  ...   0.7430
# 5   stokes mistakenly applies saliva ball 2nd time...  ...  -0.5574
# 6   hardik runs towards sam curran getting sledged...  ...  -0.4215
# 7   pant denied 4 runs despite ball crossing bound...  ...  -0.4393
# 8   never played hundreds life kohli not hitting t...  ...   0.5520
# 9   cricket world cup super league points table re...  ...   0.4019
# 10  3rd umpires decision indias runout appeal stok...  ...   0.0000
# 11  phone gavaskar welcome give ring bairstow crit...  ...   0.8689
# 12   risky vvs laxman indias 5bowler strategy england  ...   0.0772
# 13  sehwag criticises indias decision not bowl har...  ...  -0.6968
# 14  teams wearing human rights tshirts fifa world ...  ...  -0.4019
# 15  adil rashid 2nd bowler dismiss kohli 9 times i...  ...   0.0000
# 16  faced haryana mens team bowlers improve 17yrol...  ...   0.4404
# 17  saina enters semifinals tournament 1st time 2 ...  ...  -0.4767
# 18  disappointed gavaskar kohlis 7 50 scores last ...  ...  -0.1280
# 19    really honoured shakib al hasan meeting pm modi  ...   0.7269
# 20  say indias decision make domestic vaccinations...  ...   0.4449
# 21  earth safe 100 yrs asteroid apophis risk list ...  ...   0.1027
# 22  undiplomatic india saudis advice tackling oil ...  ...  -0.4019
# 23  us adds india list regions affected african sw...  ...   0.2023
# 24  pm modi prays maa kali free human race covid19...  ...   0.2500
# 25  satellite images show traffic jam caused conta...  ...  -0.0516
# 26  pakistan interior ministry refuses renew expm ...  ...  -0.5859
# 27  plan made refloat huge container ship blocking...  ...   0.3182
# 28  myanmar civil disobedience movement nominated ...  ...   0.8910
# 29        fake coronavirus vaccines sold online warns  ...  -0.7717
# 30  urges countries donate 1 crore vaccine doses i...  ...   0.4939
# 31  thailand plans allow quarantinefree entry vacc...  ...   0.7783
# 32  britains medicine regulator approves 20second ...  ...   0.7717
# 33  fb freezes venezuela prezs page covid19 misinf...  ...  -0.8402
# 34  biden invites 40 world leaders including pm mo...  ...   0.6369
# 35  jica extend 3717 cr loan fund 2nd phase bengal...  ...   0.9246
# 36  us firm sues fox news 16 bn false us election ...  ...  -0.8555
# 37  oil jumps 4 fears suez canal blockage may last...  ...  -0.9442
# 38  pak successfully test fires nuclearcapable bal...  ...   0.2500
# 39   china imposes duties 218 australian wine 5 years  ...  -0.8271
# 40  voting begins 1st phase assembly elections ass...  ...   0.0000
# 41  100 evms found nonfunctional several areas wb ...  ...   0.3400
# 42  shashi tharoor says sorry tweet pm modis speec...  ...  -0.2500
# 43  tea leaves not fully grown priyanka plucks pho...  ...  -0.2500
# 44  sc orders transfer mla ansari punjab pending c...  ...   0.0516
# 45  gold smuggling accused not held 9 months keral...  ...  -0.4512
# 46  vote wisely manmohan singh video message ahead...  ...   0.2732
# 47  kerala govt orders judicial probe ed gold smug...  ...  -0.8020
# 48  hotel rooms near gir sanctuary rose 25 2500 20...  ...   0.1531
# 49  uttar pradesh panchayat polls held 4 phases ap...  ...   0.0000
# 50        caa brought divide people country kerala cm  ...  -0.5574
# 51  bjp announces candidates lok sabha bypolls acr...  ...  -0.3612
# 52  5 hurt explosion tmc office bengals bankura ah...  ...  -0.4019
# 53  ruckus bihar assembly attack democracy rs depu...  ...  -0.7579
# 54   many deaths state waiting fadnavis hospital fire  ...  -0.7717
# 55  I farmer tamil nadu cm dmk leaders slipper remark  ...   0.1280
# 56  suvendu writes ec seeks several police officer...  ...   0.2960
# 57  tmc workers trying create disturbance bjp cand...  ...  -0.4404
# 58     congress stages protests farm laws maharashtra  ...  -0.5719
# 59  vehicle returning delivering food wb poll work...  ...  -0.4215
#
# [60 rows x 4 columns]

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.7/dist-packages (0.79.0)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (4.2.1)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.5.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (7.0.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (7.1.2)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (3.12.4)
# Requirement already satisfied: validators in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.18.2)
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.23.0)
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.8.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from streamlit) (20.9)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (4.1.0)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (5.1.1)
# Requirement already satisfied: watchdog; platform_system != "Darwin" in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: base58 in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.1.0)
# Requirement already satisfied: pyarrow; python_version < "3.9" in /usr/local/lib/python3.7/dist-packages (from streamlit) (3.0.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.19.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.8.1)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.6.1)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.7/dist-packages (from streamlit) (3.1.14)
# Requirement already satisfied: blinker in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from tzlocal->streamlit) (2018.9)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf!=3.11,>=3.6.0->streamlit) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf!=3.11,>=3.6.0->streamlit) (54.1.2)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from validators->streamlit) (4.4.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (2020.12.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (2.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit) (5.5.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython->streamlit) (4.0.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (5.3.5)
# Requirement already satisfied: smmap<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython->streamlit) (4.0.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.6.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.7.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.3.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (22.0.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.2)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.3.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)

# %%
# %%writefile app.py
import requests
from bs4 import BeautifulSoup
import streamlit as st
import pandas as pd
import numpy as np
import nltk
import contractions
import re 
import nltk
nltk.download('stopwords')
stopword_list=nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer=ToktokTokenizer()
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs=SentimentIntensityAnalyzer()
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
 
def html_tag(text):
  soup=BeautifulSoup(text,"html.parser")
  news_text=soup.get_text()
  return news_text 
 
def con(text):
  expand=contractions.fix(text) 
  return expand
 
def remove_sp(text):
  pattern=r'[^A-Za-z0-9\s]'
  text=re.sub(pattern,'',text) 
  return text
 
def remove_stopwords(text):
  tokens=tokenizer.tokenize(text)
  tokens=[token.strip() for token in tokens]
  filtered_tokens=[token for token in tokens if token not in stopword_list]
  filtered_text=' '.join(filtered_tokens) 
  return filtered_text
 
df = pd.read_csv('https://raw.githubusercontent.com/LavanyaPanja/Sentiment_Analysis_Using_Python/main/news.csv')
 
df.news_headline=df.news_headline.apply(lambda x:x.lower())
df.news_article=df.news_article.apply(lambda x:x.lower()) 
df.news_headline=df.news_headline.apply(html_tag)
df.news_article=df.news_article.apply(html_tag)
 
df.news_headline=df.news_headline.apply(con)
df.news_article=df.news_article.apply(con)
df.news_headline=df.news_headline.apply(remove_sp)
df.news_article=df.news_article.apply(remove_sp)
df.news_headline=df.news_headline.apply(remove_stopwords)
df.news_article=df.news_article.apply(remove_stopwords)
df['compound']=df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])
x = df.iloc[:,1].values # Message column as input
y = df.iloc[:,0].values # Label column as output
 
st.title('SENTIMENT ANALYSIS USING PYTHON')
st.subheader('PREDICTS DATA HOW MUCH IT WILL HAVE POSITIVITY , NEGATIVITY AND NUETRAL')
 
text_model=Pipeline([('tfidf',TfidfVectorizer()),('model',MultinomialNB())])
text_model.fit(x,y)
message = st.text_area("Enter Text")
text_model.predict([message]) 
 
if st.button("Predict"):
  msg=html_tag(message.lower())
  msg=con(msg) 
  msg=remove_sp(msg) 
  msg=remove_stopwords(msg) 
  st.subheader('OUTPUT') 
  st.text(msg) 
  text=vs.polarity_scores(msg) 
  st.subheader('THE POLARITY SCORE IS:') 
  st.title(text)
# Out:
# Overwriting app.py

# %%
# !pip install pyngrok==4.1.1
from pyngrok import ngrok
url=ngrok.connect(port='8501')
url
# Out:
# Requirement already satisfied: pyngrok==4.1.1 in /usr/local/lib/python3.7/dist-packages (4.1.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok==4.1.1) (3.13)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyngrok==4.1.1) (0.16.0)
# 'http://63a615593871.ngrok.io'

# %%
# !nohup streamlit run app.py &
# Out:
# nohup: appending output to 'nohup.out'
